# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/users/robbieardison/desktop/liverpool_data_squad.xltx')
df.head()
# Out:
#                    Player Nation Pos  Age  Caps  Starts   Min   90s  Goals  \
# 0                 Alisson    BRA  GK   29    29      29  2610  29.0      0
# 1         Virgil van Dijk    NED  DF   30    29      29  2610  29.0      3
# 2           Mohamed Salah    EGY  FW   29    29      27  2418  26.9     20
# 3  Trent Alexander-Arnold    ENG  DF   23    27      27  2403  26.7      2
# 4              Sadio Mané    SEN  FW   30    28      26  2332  25.9     13
#
#    Assists  ...  G+A-PK    xG  npxG   xA  npxG+xA  xG.1  xA.1  xG+xA  npxG.1  \
# 0        1  ...    0.03   0.0   0.0  0.4      0.4  0.00  0.02   0.02    0.00
# 1        1  ...    0.14   2.1   2.1  0.3      2.3  0.07  0.01   0.08    0.07
# 2       11  ...    0.97  19.1  14.4  9.3     23.7  0.71  0.35   1.06    0.54
# 3       12  ...    0.52   2.3   2.3  9.9     12.2  0.09  0.37   0.46    0.09
# 4        1  ...    0.54  14.9  14.9  3.6     18.5  0.57  0.14   0.71    0.57
#
#    npxG+xA.1
# 0       0.02
# 1       0.08
# ...

# %%
df.sort_values(by='Goals', ascending=False)
# Out:
#                      Player Nation   Pos  Age  Caps  Starts   Min   90s  \
# 2             Mohamed Salah    EGY    FW   29    29      27  2418  26.9
# 9                Diogo Jota    POR    FW   25    28      22  1909  21.2
# 4                Sadio Mané    SEN    FW   30    28      26  2332  25.9
# 12          Roberto Firmino    BRA    FW   30    18       9   887   9.9
# 8                   Fabinho    BRA    MF   28    24      22  2001  22.2
# 1           Virgil van Dijk    NED    DF   30    29      29  2610  29.0
# 11               Naby Keïta    GUI    MF   27    16      10   843   9.4
# 23          Takumi Minamino    JPN  FWMF   27    10       0    96   1.1
# 18                Luis Díaz    COL    FW   25     7       6   517   5.7
# 13  Alex Oxlade-Chamberlain    ENG  MFFW   28    17       9   785   8.7
# 24             Divock Origi    BEL    FW   26     5       0    76   0.8
# 6          Jordan Henderson    ENG    MF   31    28      25  2170  24.1
# ...

# %%
plt.figure(figsize=(15,8))
topscorers = df.sort_values(by='Goals', ascending=False)
top10scorers = topscorers[['Player', 'Goals']]
top10scorers.plot(kind='bar')
# Out:
# <AxesSubplot:>
